# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
from citation_analyzer.citation_extractor import extract
from citation_analyzer.utils import load_json, llm_call
import dotenv
from tqdm import tqdm
import json

dotenv.load_dotenv()
# Out:
# True

# %%
def read_data():
    df_1 = pd.read_csv("/Users/ahmed/Desktop/msc-24/TND/kc_classification_data/pre_cutoff_data/df_1.csv")
    list_1 = df_1["file_path"].to_list()

    df_2 = pd.read_csv("/Users/ahmed/Desktop/msc-24/TND/kc_classification_data/pre_cutoff_data/df_2.csv")
    list_2 = df_2["file_path"].to_list()

    df_3 = pd.read_csv("/Users/ahmed/Desktop/msc-24/TND/kc_classification_data/pre_cutoff_data/df_3.csv")
    list_3 = df_3["file_path"].to_list()

    df_4 = pd.read_csv("/Users/ahmed/Desktop/msc-24/TND/kc_classification_data/pre_cutoff_data/df_4.csv")
    list_4 = df_4["file_path"].to_list()

    return list_1[:5], list_2[:5], list_3[:5], list_4[:5]

# %%
list_1, list_2, list_3, list_4 = read_data()

# %%
list_1[2]
# Out:
# '001-219943.json'

# %%
file_name = list_1[2]

ids_map, citation_contexts = extract(file_name)

# %%
ids_map
# Out:
# {'001-219943': ['001-57827',
#   '001-58068',
#   '001-81608',
#   '001-158290',
#   '001-81608',
#   '001-217387',
#   '001-59470',
#   '001-122186',
#   '001-103285',
#   '001-115160',
#   '001-156070',
#   '001-171804',
#   '001-103285',
#   '001-115160',
#   '001-156070',
#   '001-171804',
#   '001-203213',
#   '001-203213',
#   '001-217039']}

# %%
citation_contexts
# Out:
# [{'full_citation': '(see Kokkinakis v. Greece, 25 May 1993',
#   'case_name': 'Kokkinakis v. Greece',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': None,
#   'paragraphs_in_cited_case': '',
#   'start_paragraph_in_cited_case': None,
#   'end_paragraph_in_cited_case': None,
#   'date': '25 May 1993',
#   'citing_paragraph': '38.  It is a logical consequence of the principle that laws must be of general application that the wording of statutes is not always precise. One of the standard techniques of regulation by rules is to use general categorisations as opposed to exhaustive lists. Accordingly, many laws are inevitably couched in terms which, to a greater or lesser extent, are vague and whose interpretation and application are questions of practice (see Kokkinakis v. Greece, 25 May 1993, § 40, Series A no. 260A; Del Río Prada, cited above, § 92; and Advisory opinion P16-2021-001, cited above, § 67). When the legislative technique of categorisation is used, there will often be grey areas at the fringes of the definition. This penumbra of doubt in relation to borderline facts does not in itself make a provision incompatible with Article 7, provided that it proves to be sufficiently clear in the large majority of cases (see Cantoni v. France, 15 November 1996, § 32, Reports of Judgments and Decisions 1996V).'},
#  {'full_citation': '(see Cantoni v. France, 15 November 1996',
#   'case_name': 'Cantoni v. France',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': None,
#   'paragraphs_in_cited_case': '',
#   'start_paragraph_in_cited_case': None,
#   'end_paragraph_in_cited_case': None,
#   'date': '15 November 1996',
#   'citing_paragraph': '38.  It is a logical consequence of the principle that laws must be of general application that the wording of statutes is not always precise. One of the standard techniques of regulation by rules is to use general categorisations as opposed to exhaustive lists. Accordingly, many laws are inevitably couched in terms which, to a greater or lesser extent, are vague and whose interpretation and application are questions of practice (see Kokkinakis v. Greece, 25 May 1993, § 40, Series A no. 260A; Del Río Prada, cited above, § 92; and Advisory opinion P16-2021-001, cited above, § 67). When the legislative technique of categorisation is used, there will often be grey areas at the fringes of the definition. This penumbra of doubt in relation to borderline facts does not in itself make a provision incompatible with Article 7, provided that it proves to be sufficiently clear in the large majority of cases (see Cantoni v. France, 15 November 1996, § 32, Reports of Judgments and Decisions 1996V).'},
#  {'full_citation': 'Jorgic v. Germany, no. 74613/01, § 102, ECHR 2007',
#   'case_name': 'Jorgic v. Germany',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 74613/01',
#   'paragraphs_in_cited_case': '§ 102',
#   'start_paragraph_in_cited_case': 102,
#   'end_paragraph_in_cited_case': 102,
#   'date': 'ECHR 2007',
#   'citing_paragraph': "39.  The Court reiterates its settled case-law to the effect that it is primarily for the national authorities to interpret and apply domestic law (see, inter alia, Del Río Prada, cited above, § 105 and Jorgic v. Germany, no. 74613/01, § 102, ECHR 2007-III.) However, when a Convention right itself, Article 7 in the present case, requires that there was a legal basis for a conviction and sentence, the Court's powers of review encompass an examination of whether the result reached by the domestic courts was compatible with Article 7 of the Convention, even if there were differences between the legal approach and reasoning of this Court and the relevant domestic decisions. To accord a lesser power of review to this Court would render Article 7 devoid of its purpose (see, for example, Vasiliauskas v. Lithuania, cited above, §§ 160161)."},
#  {'full_citation': 'Vasiliauskas v. Lithuania, ',
#   'case_name': 'Vasiliauskas v. Lithuania',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': None,
#   'paragraphs_in_cited_case': '',
#   'start_paragraph_in_cited_case': None,
#   'end_paragraph_in_cited_case': None,
#   'date': None,
#   'citing_paragraph': "39.  The Court reiterates its settled case-law to the effect that it is primarily for the national authorities to interpret and apply domestic law (see, inter alia, Del Río Prada, cited above, § 105 and Jorgic v. Germany, no. 74613/01, § 102, ECHR 2007-III.) However, when a Convention right itself, Article 7 in the present case, requires that there was a legal basis for a conviction and sentence, the Court's powers of review encompass an examination of whether the result reached by the domestic courts was compatible with Article 7 of the Convention, even if there were differences between the legal approach and reasoning of this Court and the relevant domestic decisions. To accord a lesser power of review to this Court would render Article 7 devoid of its purpose (see, for example, Vasiliauskas v. Lithuania, cited above, §§ 160161)."},
#  {'full_citation': 'Jorgic v. Germany, ',
#   'case_name': 'Jorgic v. Germany',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': None,
#   'paragraphs_in_cited_case': '',
#   'start_paragraph_in_cited_case': None,
#   'end_paragraph_in_cited_case': None,
#   'date': None,
#   'citing_paragraph': ".  Having regard to the above, the Court cannot find any grounds on which to criticise the domestic courts' finding in this respect (see paragraph 40 above). It is satisfied, having regard to the wording of section 114j and the preparatory notes, that the offence was clearly defined in the law and fulfilled the requirements notably of accessibility and foreseeability (see, for example, Jorgic v. Germany, cited above, § 100). It follows that there has been no violation of Article 7 regarding this complaint."},
#  {'full_citation': 'Scoppola cited above and Sinan Çetinkaya and Ağyar Çetinkaya v. Turkey, no. 74536/10, 24 May 2022)',
#   'case_name': 'Scoppola cited above and Sinan Çetinkaya and Ağyar Çetinkaya v. Turkey',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 74536/10',
#   'paragraphs_in_cited_case': '',
#   'start_paragraph_in_cited_case': None,
#   'end_paragraph_in_cited_case': None,
#   'date': '24 May 2022',
#   'citing_paragraph': '52.  The Court observes that the present case significantly differs from its previous case-law on the principle of the retroactivity of the more lenient criminal law. It recalls that it has found a violation in cases where the criminal law or the criminal procedure were amended (see, among others, Scoppola cited above and Sinan Çetinkaya and Ağyar Çetinkaya v. Turkey, no. 74536/10, 24 May 2022), or where the domestic courts subsequently exercised their judicial discretion in an expansive manner by adopting an interpretation that was inconsistent with both prevailing national jurisprudence and the essence of the offence as defined by the national law (see, for example, Parmak and Bakır, cited above). In the present case, however, the Penal Code and procedure remained unchanged. The amendment in the 2019 Executive Order only related to changed factual circumstances that had occurred after the time of the offence, resulting from specific changes in the situation in Syria. It was thus unrelated to the assessment of the criminal act committed in 2016/2017 (see paragraph 17 above).'},
#  {'full_citation': 'Baumann v. France, no. 33592/96, § 61, ECHR 2001',
#   'case_name': 'Baumann v. France',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 33592/96',
#   'paragraphs_in_cited_case': '§ 61',
#   'start_paragraph_in_cited_case': 61,
#   'end_paragraph_in_cited_case': 61,
#   'date': 'ECHR 2001',
#   'citing_paragraph': "61.  The Court reiterates that Article 2 of Protocol No. 4 guarantees that everyone shall be free to leave any country, including his own. The provision does not directly address restrictions on going to certain areas in other countries. Nevertheless, it implies the right to travel to any country of the person's choice to which he or she may be admitted (see, inter alia, Baumann v. France, no. 33592/96, § 61, ECHR 2001-V, and Khlyustov v. Russia, no. 28975/05, § 64, 11 July 2013)."},
#  {'full_citation': 'Khlyustov v. Russia, no. 28975/05, § 64, 11',
#   'case_name': 'Khlyustov v. Russia',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 28975/05',
#   'paragraphs_in_cited_case': '§ 64, 11',
#   'start_paragraph_in_cited_case': 64,
#   'end_paragraph_in_cited_case': 64,
#   'date': None,
#   'citing_paragraph': "61.  The Court reiterates that Article 2 of Protocol No. 4 guarantees that everyone shall be free to leave any country, including his own. The provision does not directly address restrictions on going to certain areas in other countries. Nevertheless, it implies the right to travel to any country of the person's choice to which he or she may be admitted (see, inter alia, Baumann v. France, no. 33592/96, § 61, ECHR 2001-V, and Khlyustov v. Russia, no. 28975/05, § 64, 11 July 2013)."},
#  {'full_citation': '(see Nalbantski v. Bulgaria, no. 30943/04, § 61, 10',
#   'case_name': 'Nalbantski v. Bulgaria',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 30943/04',
#   'paragraphs_in_cited_case': '§ 61, 10',
#   'start_paragraph_in_cited_case': 61,
#   'end_paragraph_in_cited_case': 61,
#   'date': None,
#   'citing_paragraph': '62.  In the present case the applicant was free to leave Denmark. However, in the context of preventing participation in armed conflicts abroad, under section 114j (1) read with section 114j (3) of the Penal Code, and section 1 (1) of the 2016 Executive Order, he was, as a Danish national, prohibited from entering and staying in the al-Raqqa district in Syria without permission by the Danish State. Proceeding on the assumption that such a restriction falls under Article 2 of Protocol No. 4, it must therefore be examined whether the interference was "in accordance with law", pursued one or more of the legitimate aims set out in Article 2 § 3 of Protocol No. 4 and was "necessary in a democratic society" to achieve such an aim (see Nalbantski v. Bulgaria, no. 30943/04, § 61, 10 February 2011; Stamose v. Bulgaria, no. 29713/05, § 30, ECHR 2012; Kerimli v. Azerbaijan, no. 3967/09, § 45, 16 July 2015; and De Tommaso v. Italy [GC], no. , § 105, 23 February 2017).'},
#  {'full_citation': 'February 2011; Stamose v. Bulgaria, no. 29713/05, § 30, ECHR 2012',
#   'case_name': 'February 2011; Stamose v. Bulgaria',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 29713/05',
#   'paragraphs_in_cited_case': '§ 30',
#   'start_paragraph_in_cited_case': 30,
#   'end_paragraph_in_cited_case': 30,
#   'date': 'ECHR 2012',
#   'citing_paragraph': '62.  In the present case the applicant was free to leave Denmark. However, in the context of preventing participation in armed conflicts abroad, under section 114j (1) read with section 114j (3) of the Penal Code, and section 1 (1) of the 2016 Executive Order, he was, as a Danish national, prohibited from entering and staying in the al-Raqqa district in Syria without permission by the Danish State. Proceeding on the assumption that such a restriction falls under Article 2 of Protocol No. 4, it must therefore be examined whether the interference was "in accordance with law", pursued one or more of the legitimate aims set out in Article 2 § 3 of Protocol No. 4 and was "necessary in a democratic society" to achieve such an aim (see Nalbantski v. Bulgaria, no. 30943/04, § 61, 10 February 2011; Stamose v. Bulgaria, no. 29713/05, § 30, ECHR 2012; Kerimli v. Azerbaijan, no. 3967/09, § 45, 16 July 2015; and De Tommaso v. Italy [GC], no. , § 105, 23 February 2017).'},
#  {'full_citation': 'Kerimli v. Azerbaijan, no. 3967/09, § 45, 16',
#   'case_name': 'Kerimli v. Azerbaijan',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 3967/09',
#   'paragraphs_in_cited_case': '§ 45, 16',
#   'start_paragraph_in_cited_case': 45,
#   'end_paragraph_in_cited_case': 45,
#   'date': None,
#   'citing_paragraph': '62.  In the present case the applicant was free to leave Denmark. However, in the context of preventing participation in armed conflicts abroad, under section 114j (1) read with section 114j (3) of the Penal Code, and section 1 (1) of the 2016 Executive Order, he was, as a Danish national, prohibited from entering and staying in the al-Raqqa district in Syria without permission by the Danish State. Proceeding on the assumption that such a restriction falls under Article 2 of Protocol No. 4, it must therefore be examined whether the interference was "in accordance with law", pursued one or more of the legitimate aims set out in Article 2 § 3 of Protocol No. 4 and was "necessary in a democratic society" to achieve such an aim (see Nalbantski v. Bulgaria, no. 30943/04, § 61, 10 February 2011; Stamose v. Bulgaria, no. 29713/05, § 30, ECHR 2012; Kerimli v. Azerbaijan, no. 3967/09, § 45, 16 July 2015; and De Tommaso v. Italy [GC], no. , § 105, 23 February 2017).'},
#  {'full_citation': 'July 2015; and De Tommaso v. Italy [GC], no. , § 105, 23',
#   'case_name': 'July 2015; and De Tommaso v. Italy',
#   'parenthetical': '[GC]',
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no.',
#   'paragraphs_in_cited_case': '§ 105, 23',
#   'start_paragraph_in_cited_case': 105,
#   'end_paragraph_in_cited_case': 105,
#   'date': None,
#   'citing_paragraph': '62.  In the present case the applicant was free to leave Denmark. However, in the context of preventing participation in armed conflicts abroad, under section 114j (1) read with section 114j (3) of the Penal Code, and section 1 (1) of the 2016 Executive Order, he was, as a Danish national, prohibited from entering and staying in the al-Raqqa district in Syria without permission by the Danish State. Proceeding on the assumption that such a restriction falls under Article 2 of Protocol No. 4, it must therefore be examined whether the interference was "in accordance with law", pursued one or more of the legitimate aims set out in Article 2 § 3 of Protocol No. 4 and was "necessary in a democratic society" to achieve such an aim (see Nalbantski v. Bulgaria, no. 30943/04, § 61, 10 February 2011; Stamose v. Bulgaria, no. 29713/05, § 30, ECHR 2012; Kerimli v. Azerbaijan, no. 3967/09, § 45, 16 July 2015; and De Tommaso v. Italy [GC], no. , § 105, 23 February 2017).'},
#  {'full_citation': '(see Nalbantski v. Bulgaria, no. 30943/04, § 61, 10',
#   'case_name': 'Nalbantski v. Bulgaria',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 30943/04',
#   'paragraphs_in_cited_case': '§ 61, 10',
#   'start_paragraph_in_cited_case': 61,
#   'end_paragraph_in_cited_case': 61,
#   'date': None,
#   'citing_paragraph': '62.  In the present case the applicant was free to leave Denmark. However, in the context of preventing participation in armed conflicts abroad, under section 114j (1) read with section 114j (3) of the Penal Code, and section 1 (1) of the 2016 Executive Order, he was, as a Danish national, prohibited from entering and staying in the al-Raqqa district in Syria without permission by the Danish State. Proceeding on the assumption that such a restriction falls under Article 2 of Protocol No. 4, it must therefore be examined whether the interference was "in accordance with law", pursued one or more of the legitimate aims set out in Article 2 § 3 of Protocol No. 4 and was "necessary in a democratic society" to achieve such an aim (see Nalbantski v. Bulgaria, no. 30943/04, § 61, 10 February 2011; Stamose v. Bulgaria, no. 29713/05, § 30, ECHR 2012; Kerimli v. Azerbaijan, no. 3967/09, § 45, 16 July 2015; and De Tommaso v. Italy [GC], no. , § 105, 23 February 2017).'},
#  {'full_citation': 'February 2011; Stamose v. Bulgaria, no. 29713/05, § 30, ECHR 2012',
#   'case_name': 'February 2011; Stamose v. Bulgaria',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 29713/05',
#   'paragraphs_in_cited_case': '§ 30',
#   'start_paragraph_in_cited_case': 30,
#   'end_paragraph_in_cited_case': 30,
#   'date': 'ECHR 2012',
#   'citing_paragraph': '62.  In the present case the applicant was free to leave Denmark. However, in the context of preventing participation in armed conflicts abroad, under section 114j (1) read with section 114j (3) of the Penal Code, and section 1 (1) of the 2016 Executive Order, he was, as a Danish national, prohibited from entering and staying in the al-Raqqa district in Syria without permission by the Danish State. Proceeding on the assumption that such a restriction falls under Article 2 of Protocol No. 4, it must therefore be examined whether the interference was "in accordance with law", pursued one or more of the legitimate aims set out in Article 2 § 3 of Protocol No. 4 and was "necessary in a democratic society" to achieve such an aim (see Nalbantski v. Bulgaria, no. 30943/04, § 61, 10 February 2011; Stamose v. Bulgaria, no. 29713/05, § 30, ECHR 2012; Kerimli v. Azerbaijan, no. 3967/09, § 45, 16 July 2015; and De Tommaso v. Italy [GC], no. , § 105, 23 February 2017).'},
#  {'full_citation': 'Kerimli v. Azerbaijan, no. 3967/09, § 45, 16',
#   'case_name': 'Kerimli v. Azerbaijan',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 3967/09',
#   'paragraphs_in_cited_case': '§ 45, 16',
#   'start_paragraph_in_cited_case': 45,
#   'end_paragraph_in_cited_case': 45,
#   'date': None,
#   'citing_paragraph': '62.  In the present case the applicant was free to leave Denmark. However, in the context of preventing participation in armed conflicts abroad, under section 114j (1) read with section 114j (3) of the Penal Code, and section 1 (1) of the 2016 Executive Order, he was, as a Danish national, prohibited from entering and staying in the al-Raqqa district in Syria without permission by the Danish State. Proceeding on the assumption that such a restriction falls under Article 2 of Protocol No. 4, it must therefore be examined whether the interference was "in accordance with law", pursued one or more of the legitimate aims set out in Article 2 § 3 of Protocol No. 4 and was "necessary in a democratic society" to achieve such an aim (see Nalbantski v. Bulgaria, no. 30943/04, § 61, 10 February 2011; Stamose v. Bulgaria, no. 29713/05, § 30, ECHR 2012; Kerimli v. Azerbaijan, no. 3967/09, § 45, 16 July 2015; and De Tommaso v. Italy [GC], no. , § 105, 23 February 2017).'},
#  {'full_citation': 'July 2015; and De Tommaso v. Italy [GC], no. , § 105, 23',
#   'case_name': 'July 2015; and De Tommaso v. Italy',
#   'parenthetical': '[GC]',
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no.',
#   'paragraphs_in_cited_case': '§ 105, 23',
#   'start_paragraph_in_cited_case': 105,
#   'end_paragraph_in_cited_case': 105,
#   'date': None,
#   'citing_paragraph': '62.  In the present case the applicant was free to leave Denmark. However, in the context of preventing participation in armed conflicts abroad, under section 114j (1) read with section 114j (3) of the Penal Code, and section 1 (1) of the 2016 Executive Order, he was, as a Danish national, prohibited from entering and staying in the al-Raqqa district in Syria without permission by the Danish State. Proceeding on the assumption that such a restriction falls under Article 2 of Protocol No. 4, it must therefore be examined whether the interference was "in accordance with law", pursued one or more of the legitimate aims set out in Article 2 § 3 of Protocol No. 4 and was "necessary in a democratic society" to achieve such an aim (see Nalbantski v. Bulgaria, no. 30943/04, § 61, 10 February 2011; Stamose v. Bulgaria, no. 29713/05, § 30, ECHR 2012; Kerimli v. Azerbaijan, no. 3967/09, § 45, 16 July 2015; and De Tommaso v. Italy [GC], no. , § 105, 23 February 2017).'},
#  {'full_citation': 'Baldassi and Others v. France, nos. 15271/16 and 6 others, §§ 41',
#   'case_name': 'Baldassi and Others v. France',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'nos. 15271/16 and 6 others',
#   'paragraphs_in_cited_case': '§§ 41',
#   'start_paragraph_in_cited_case': 41,
#   'end_paragraph_in_cited_case': 41,
#   'date': None,
#   'citing_paragraph': '63.  In respect of lawfulness, the Court refers to its findings under Article 7 of the Convention (see paragraphs 40 to 44 above; see also, for example, Baldassi and Others v. France, nos. 15271/16 and 6 others, §§ 41 and 59, 11 June 2020).'},
#  {'full_citation': 'Baldassi and Others v. France, nos. 15271/16 and 6 others, §§ 41',
#   'case_name': 'Baldassi and Others v. France',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'nos. 15271/16 and 6 others',
#   'paragraphs_in_cited_case': '§§ 41',
#   'start_paragraph_in_cited_case': 41,
#   'end_paragraph_in_cited_case': 41,
#   'date': None,
#   'citing_paragraph': '63.  In respect of lawfulness, the Court refers to its findings under Article 7 of the Convention (see paragraphs 40 to 44 above; see also, for example, Baldassi and Others v. France, nos. 15271/16 and 6 others, §§ 41 and 59, 11 June 2020).'},
#  {'full_citation': 'Lings v. Denmark, no. 15136/20, § 58, 12',
#   'case_name': 'Lings v. Denmark',
#   'parenthetical': None,
#   'committee': None,
#   'footnote': None,
#   'application_numbers': 'no. 15136/20',
#   'paragraphs_in_cited_case': '§ 58, 12',
#   'start_paragraph_in_cited_case': 58,
#   'end_paragraph_in_cited_case': 58,
#   'date': None,
#   'citing_paragraph': '.  The Court considers that the quality of the judicial review of the disputed general measure and its application in the present case militates in favour of a wide margin of appreciation (see, mutatis mutandis, Lings v. Denmark, no. 15136/20, § 58, 12 April 2022).'}]
